# %%
import os
import pandas as pd

# %%
student_data1=pd.DataFrame({
    'student_id':['S1','S2','S3','S4','S5'],
    'name':['Danniella Fenton','Ryder Storey','Bryce Jensen','Ed Bernal','Kwame Morin'],
    'marks':[200,210,190,222,199]})
student_data2=pd.DataFrame({
    'student_id':['S4','S5','S6','S7','S8'],
    'name':['Scarlette Fisher','Carla Williamson','Dante Morse','Katelyn Russell','Madeeha Preston'],
    'marks':[201,200,198,219,201]
})
exam_data=pd.DataFrame({
    'student_id':['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12','S13'],
    'exam_id':[23,40,103,101,101,104,101,100,103,102,105,106,107]})

# %%
student_data1
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199

# %%
student_data2
# Out:
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7   Katelyn Russell    219
# 4         S8   Madeeha Preston    201

# %%
parent_directory=os.path.join(os.getcwd(),"files")

student_data1.to_csv(os.path.join(parent_directory,"student_data1.csv"),index=False)
student_data2.to_csv(os.path.join(parent_directory,"student_data2.csv"),index=False)
exam_data.to_csv(os.path.join(parent_directory,"exam_data.csv"),index=False)

# %%
stu_df1=pd.read_csv(os.path.join(parent_directory,"student_data1.csv"))
stu_df2=pd.read_csv(os.path.join(parent_directory,"student_data2.csv"))
exam_df=pd.read_csv(os.path.join(parent_directory,"exam_data.csv"))
stu_df2
# Out:
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7   Katelyn Russell    219
# 4         S8   Madeeha Preston    201

# %%
test_df=stu_df1.merge(stu_df2,how="outer")
test_df
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S4  Scarlette Fisher    201
# 5         S5  Carla Williamson    200
# 6         S5       Kwame Morin    199
# 7         S6       Dante Morse    198
# 8         S7   Katelyn Russell    219
# 9         S8   Madeeha Preston    201

# %%
test_df.merge(exam_df,how="outer").fillna("")
# Out:
#    student_id              name  marks  exam_id
# 0          S1  Danniella Fenton  200.0       23
# 1         S10                               102
# 2         S11                               105
# 3         S12                               106
# 4         S13                               107
# 5          S2      Ryder Storey  210.0       40
# 6          S3      Bryce Jensen  190.0      103
# 7          S4         Ed Bernal  222.0      101
# 8          S4  Scarlette Fisher  201.0      101
# 9          S5  Carla Williamson  200.0      101
# 10         S5       Kwame Morin  199.0      101
# 11         S6       Dante Morse  198.0      104
# 12         S7   Katelyn Russell  219.0      101
# 13         S8   Madeeha Preston  201.0      100
# 14         S9                               103

# %%
stu_df1.merge(stu_df2,how="inner",on='student_id')
# Out:
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal      222  Scarlette Fisher      201
# 1         S5  Kwame Morin      199  Carla Williamson      200

# %%
pd.concat([stu_df1,stu_df2])
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7   Katelyn Russell    219
# 4         S8   Madeeha Preston    201
